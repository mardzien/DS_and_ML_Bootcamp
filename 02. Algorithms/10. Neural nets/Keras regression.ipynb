# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('DATA/kc_house_data.csv')

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().T
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
plt.figure(figsize=(12,9))
sns.histplot([df['price']], kde=True)
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
sns.countplot(data=df, x='bedrooms')
# Out:
# <AxesSubplot: xlabel='bedrooms', ylabel='count'>

# %%
df.corr(numeric_only=True)['price']
# Out:
# id              -0.016772
# price            1.000000
# bedrooms         0.308787
# bathrooms        0.525906
# sqft_living      0.701917
# sqft_lot         0.089876
# floors           0.256804
# waterfront       0.266398
# view             0.397370
# condition        0.036056
# grade            0.667951
# sqft_above       0.605368
# sqft_basement    0.323799
# yr_built         0.053953
# yr_renovated     0.126424
# zipcode         -0.053402
# lat              0.306692
# long             0.022036
# sqft_living15    0.585241
# sqft_lot15       0.082845
# Name: price, dtype: float64

# %%
plt.figure(figsize=(12,9))
sns.scatterplot(data=df, x='price', y='sqft_living')
# Out:
# <AxesSubplot: xlabel='price', ylabel='sqft_living'>

# %%
plt.figure(figsize=(12,9))
sns.boxplot(data=df, x='bedrooms', y='price')
# Out:
# <AxesSubplot: xlabel='bedrooms', ylabel='price'>

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
plt.figure(figsize=(12,9))
sns.scatterplot(data=df, x='price', y='long')
# Out:
# <AxesSubplot: xlabel='price', ylabel='long'>

# %%
plt.figure(figsize=(12,9))
sns.scatterplot(data=df, x='price', y='lat')
# Out:
# <AxesSubplot: xlabel='price', ylabel='lat'>

# %%
plt.figure(figsize=(12,9))
sns.scatterplot(data=df, x='long', y='lat', hue='price', alpha=0.4)
# Out:
# <AxesSubplot: xlabel='long', ylabel='lat'>

# %%
df.sort_values('price', ascending=False).head(40)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df)
# Out:
# 21597

# %%
bottom_99_perc = df.sort_values('price', ascending=False).iloc[int(len(df)*0.01):]

# %%
bottom_99_perc
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 17221  1338600225   5/28/2014  1970000.0         8       3.50         4440
# 6329    824059321    6/2/2014  1970000.0         4       3.50         4370
# 12271  1923000260  10/15/2014  1960000.0         5       4.50         6200
# 9166   3124059023   2/13/2015  1960000.0         3       1.75         3330
# 12565  2806300065   4/22/2015  1960000.0         4       4.00         4430
# ...           ...         ...        ...       ...        ...          ...
# 2139   1623049041    5/8/2014    82500.0         2       1.00          520
# 8267   3883800011   11/5/2014    82000.0         3       1.00          860
# 16184  3028200080   3/24/2015    81000.0         2       1.00          730
# 465    8658300340   5/23/2014    80000.0         1       0.75          430
# 15279    40000362    5/6/2014    78000.0         2       1.00          780
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
plt.figure(figsize=(12,9))
sns.scatterplot(data=bottom_99_perc, x='long', y='lat', hue='price', edgecolor=None, palette='RdYlGn', alpha=0.4)
# Out:
# <AxesSubplot: xlabel='long', ylabel='lat'>

# %%
plt.figure(figsize=(12,9))
sns.boxplot(data=df, x='waterfront', y='price')
# Out:
# <AxesSubplot: xlabel='waterfront', ylabel='price'>

# %%
df = df.drop('id', axis=1)

# %%
df['date']
# Out:
# 0        10/13/2014
# 1         12/9/2014
# 2         2/25/2015
# 3         12/9/2014
# 4         2/18/2015
#             ...
# 21592     5/21/2014
# 21593     2/23/2015
# 21594     6/23/2014
# 21595     1/16/2015
# 21596    10/15/2014
# Name: date, Length: 21597, dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
df['year'] = df['date'].apply(lambda date: date.year)
df['month'] = df['date'].apply(lambda date: date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
plt.figure(figsize=(12,9))
sns.boxplot(data=df, x='month', y='price')
# Out:
# <AxesSubplot: xlabel='month', ylabel='price'>

# %%
plt.figure(figsize=(12,9))
sns.boxplot(data=df, x='year', y='price')
# Out:
# <AxesSubplot: xlabel='year', ylabel='price'>

# %%
df.groupby('month').mean(numeric_only=True)['price'].plot()
# Out:
# <AxesSubplot: xlabel='month'>

# %%
df.groupby('year').mean(numeric_only=True)['price'].plot()
# Out:
# <AxesSubplot: xlabel='year'>

# %%
df = df.drop('date', axis=1)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...              0      1955             0
# 1     0          3      7  ...            400      1951          1991
# 2     0          3      6  ...              0      1933             0
# 3     0          5      7  ...            910      1965             0
# 4     0          3      8  ...              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  year  month
# ...

# %%
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
df = df.drop('zipcode', axis=1)

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1951        1
# 1959        1
# 1948        1
# 1954        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# 0      13110
# 600      221
# 700      218
# 500      214
# 800      206
#        ...
# 518        1
# 374        1
# 784        1
# 906        1
# 248        1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
X = df.drop('price', axis=1).values
y = df['price'].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (15117, 19)

# %%
model = Sequential()

model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))

model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

# %%
model.fit(x=X_train, y=y_train, validation_data=(X_test, y_test),
          batch_size=128, epochs=400)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 1s 2ms/step - loss: 430234206208.0000 - val_loss: 418882060288.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 885us/step - loss: 428589023232.0000 - val_loss: 413216735232.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 925us/step - loss: 406671687680.0000 - val_loss: 364301254656.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 993us/step - loss: 308532641792.0000 - val_loss: 216687214592.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 903us/step - loss: 152826036224.0000 - val_loss: 102113968128.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 920us/step - loss: 100402569216.0000 - val_loss: 95057346560.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 1ms/step - loss: 97460051968.0000 - val_loss: 93463396352.0000
# Epoch 8/400
# ...

# %%
model.history.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses
# Out:
#              loss      val_loss
# 0    4.302342e+11  4.188821e+11
# 1    4.285890e+11  4.132167e+11
# 2    4.066717e+11  3.643013e+11
# 3    3.085326e+11  2.166872e+11
# 4    1.528260e+11  1.021140e+11
# ..            ...           ...
# 395  2.955495e+10  2.710278e+10
# 396  2.954927e+10  2.709312e+10
# 397  2.957840e+10  2.711168e+10
# 398  2.948857e+10  2.705126e+10
# 399  2.948426e+10  2.704748e+10
#
# [400 rows x 2 columns]

# %%
losses.plot()
# Out:
# <AxesSubplot: >

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score

# %%
predictions = model.predict(X_test)
# Out:
# 203/203 [==============================] - 0s 463us/step

# %%
mean_squared_error(y_test, predictions)
# Out:
# 27047472008.321095

# %%
mean_absolute_error(y_test, predictions)
# Out:
# 100506.53236159336

# %%
np.sqrt(mean_squared_error(y_test, predictions))
# Out:
# 164461.1565334535

# %%
df['price'].describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
5.402966e+05
# Out:
# 540296.6

# %%
explained_variance_score(y_test, predictions)
# Out:
# 0.7960503180402658

# %%
plt.figure(figsize=(12, 9))
plt.scatter(y_test, predictions)
plt.plot(y_test, y_test, 'r')

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21592  360000.0         3       2.50         1530      1131     3.0
# 21593  400000.0         4       2.50         2310      5813     2.0
# 21594  402101.0         2       0.75         1020      1350     2.0
# 21595  400000.0         3       2.50         1600      2388     2.0
# 21596  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %%
single_house = df.drop('price', axis=1).iloc[0]

# %%
scaled_single_house = scaler.transform(single_house.values.reshape(-1,19))

# %%
scaled_single_house
# Out:
# array([[0.2       , 0.08      , 0.08376422, 0.00310751, 0.        ,
#         0.        , 0.        , 0.5       , 0.4       , 0.10785619,
#         0.        , 0.47826087, 0.        , 0.57149751, 0.21760797,
#         0.16193426, 0.00582059, 0.        , 0.81818182]])

# %%
model.predict(scaled_single_house)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# array([[286780.94]], dtype=float32)

# %%
df.head(1)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3        1.0         1180      5650     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
#
#        lat     long  sqft_living15  sqft_lot15  year  month
# 0  47.5112 -122.257           1340        5650  2014     10
